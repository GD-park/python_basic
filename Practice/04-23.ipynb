# %%
import requests
import json
from HTMLParser import HTMLParser

api_key = '2fb372e7ce81f67b713791ac7c2882a7'
url = 'https://apis.daum.net/search/web?apikey={}&q={}&output=json'.format(api_key, '갤럭시 노트 7')

res = requests.get(url)

data = json.loads(res.text)

h = HTMLParser()
print data['channel']['item'][0]['title']
print h.unescape(data['channel']['item'][0]['title'])
# Out:
# &lt;b&gt;갤럭시 노트&lt;/b&gt;&lt;b&gt;7&lt;/b&gt; - 나무위키
# <b>갤럭시 노트</b><b>7</b> - 나무위키

# %%
client_key = 'GdW4H7wJB8lxDkaJdRmi'
client_secret = 'KXbbW2SuG3'

naver_url = 'https://openapi.naver.com/v1/search/blog.json?query=갤럭시 노트7'

headers = {}
headers['Content-Type'] = 'application/xml'
headers['X-Naver-Client-Id'] = client_key
headers['X-Naver-Client-Secret'] = client_secret

res = requests.get(naver_url, headers = headers)
print res.text
# Out:
# {
# "lastBuildDate": "Sun, 23 Apr 2017 16:07:12 +0900",
# "total": 116308,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "입가에 미소가 <b>갤럭시노트7</b> 리퍼폰",
# "link": "http://blog.naver.com/jmboss1?Redirect=Log&amp;logNo=220982191733",
# "description": "<b>갤럭시노트7</b> 리퍼폰 을 절대 받지 않겠다 다짐했지만 이번에 어쩔수 없이 리퍼폰을 받게 되었습니다 <b>갤럭시노트7</b> 리퍼폰 정말 새 제품을 받는 새로운 핸드폰을 구입한 느낌을 받았어요 !!! 어떻게보면 리퍼받길... ",
# "bloggername": "카라멜의 게임블로그",
# "bloggerlink": "http://blog.naver.com/jmboss1",
# "postdate": "20170413"
#
# },
# {
# "title": "반값 <b>갤럭시노트7</b> 리퍼폰출시되나?",
# "link": "http://blog.naver.com/boo8079?Redirect=Log&amp;logNo=220986182656",
# "description": "새로운소식 그건바록 <b>갤럭시노트7</b> 리퍼폰 이랍니다. 배터리문제로 단종되면서 쓴맛을 맛보았던... <b>갤럭시노트7</b> 홍채인식과 더블어 더욱더 좋아진 S펜그리고 깔끔한 옆면곡선으로 그립감까지 띠어났던.. 아직... ",
# "bloggername": "☆컴퓨터하는서하아빠★",
# "bloggerlink": "http://blog.naver.com/boo8079",
# "postdate": "20170418"
#
# },
# {
# "title": "발빠른 행보를 보이는 <b>갤럭시노트7</b> 리퍼폰 사전예약 출시일",
# "link": "http://blog.naver.com/berteryoyo?Redirect=Log&amp;logNo=220983557782",
# "description": "발빠른 행보를 보이는 <b>갤럭시노트7</b> 리퍼폰 출시일 및 사전예약 2월부터 꾸준하게 재기되어왔던 <b>갤럭시노트7</b> 리퍼폰 출시일이 점점 더 공식화되고 있습니다. 4월 13일 서초사옥에서 있었던 갤럭시S8 미디어... ",
# "bloggername": "멘토아이의 IT/여행/캠핑/자동차",
# "bloggerlink": "http://blog.naver.com/berteryoyo",
# "postdate": "20170414"
#
# },
# {
# "title": "<b>갤럭시노트7</b> 리퍼폰 50% 반값 구입 우주폰에서 알아보자",
# "link": "http://blog.naver.com/osj11201?Redirect=Log&amp;logNo=220987505922",
# "description": "<b>갤럭시노트7</b> 리퍼폰 50% 반값 구입 우주폰에서 알아보자 최근 <b>갤럭시노트7</b> 리퍼폰 판매에 대한 기사가 나오고 있습니다. 배터리 문제로 인해 우수한 성능과 디자인을 갖추었음에도 전량 수거해서 폐기될... ",
# "bloggername": "계란빵의 에그가 브래드를 만나다",
# "bloggerlink": "http://blog.naver.com/osj11201",
# "postdate": "20170420"
#
# },
# {
# "title": "<b>갤럭시노트7</b> 리퍼폰 가격 절반이하인이유",
# "link": "http://blog.naver.com/dicagallery?Redirect=Log&amp;logNo=220987479973",
# "description": "<b>갤럭시노트7</b> 리퍼폰 가격 50% 가격으로 부활한다구? 이번 갤럭시S8 사전예약 100만대 흥행에는 여러가지 이유가 있지만 그 중 하나는 이전제품인 <b>갤럭시노트7</b> 폭발로 인해 반납을 한 사용자들의 상실감도 한... ",
# "bloggername": "함영민의 디카갤러리",
# "bloggerlink": "http://blog.naver.com/dicagallery",
# "postdate": "20170419"
#
# },
# {
# "title": "<b>갤럭시노트7</b> 리퍼폰 어떤 모습으로 나올까?",
# "link": "http://blog.naver.com/junho6752?Redirect=Log&amp;logNo=220985247621",
# "description": "해외에서 먼저 <b>갤럭시노트7</b>R이란 이름의 리퍼폰이 출시된다는 말때문에 리퍼폰이 나올거라고 예측을 하고 있는건데요. 실패를 교훈삼아 배터리의 용량을 조금 줄이면서 (기존 <b>갤노트7</b>은 3,500mAh였습니다.)... ",
# "bloggername": "하루살이의 스마트한 블로그",
# "bloggerlink": "http://blog.naver.com/junho6752",
# "postdate": "20170417"
#
# },
# {
# "title": "<b>갤럭시노트7</b> 리퍼폰 출시일 가격할인",
# "link": "http://blog.naver.com/ynhysh?Redirect=Log&amp;logNo=220982148383",
# "description": "<b>갤럭시노트7</b> 리퍼폰 출시일이 조금 애매하다 보니까 후에 나오는 갤노트8이나 이번에 출시하는 갤럭시s8의 판매율이 어정쩡 해보이더라구요. 더군다나 아직까지 꾸준한 인기를 끌고 있는 갤럭시s7 .. 삼성... ",
# "bloggername": "ynhysh님의 블로그",
# "bloggerlink": "http://blog.naver.com/ynhysh",
# "postdate": "20170413"
#
# },
# {
# "title": "<b>갤럭시노트7</b>리퍼폰 사전예약 실시!",
# "link": "http://blog.naver.com/7andsoul?Redirect=Log&amp;logNo=220989105434",
# "description": "왕의귀환 <b>갤럭시노트7</b>리퍼폰 사전예약 실시한다고 합니다 <b>갤럭시노트7</b> 단종으로 많은 분들이 아쉬워 하셨는대 다시 <b>갤럭시노트7</b>R(가칭)으로 출시가 된다고 하네요 <b>갤럭시노트7</b> 은 스펙이나 성능에 있어서... ",
# "bloggername": "하늘지기 베가스 영상 공방(工房 )",
# "bloggerlink": "http://blog.naver.com/7andsoul",
# "postdate": "20170421"
#
# },
# {
# "title": "<b>갤럭시노트7</b> 리퍼폰 사전예약 반값 구입가능?",
# "link": "http://blog.naver.com/rde0409?Redirect=Log&amp;logNo=220989610242",
# "description": "우선 출고가가 저렴하게 출시된다는 소식과 함께, 통신사의 공시지원금을 받게되면, 최대 10~20만원 사이에서 <b>갤럭시노트7</b> 리퍼폰를 구입할 수 있을 것 같습니다. 출시는 올해 7~8월 쯤 한다는게 대략적인... ",
# "bloggername": "블루알파의 IT이야기",
# "bloggerlink": "http://blog.naver.com/rde0409",
# "postdate": "20170422"
#
# },
# {
# "title": "<b>갤럭시노트7</b> 리퍼폰 파헤쳐보자!",
# "link": "http://blog.naver.com/junhyuk0327?Redirect=Log&amp;logNo=220969765403",
# "description": "바로 <b>갤럭시노트7</b> 리퍼폰으로 재판매된다는 소식! <b>갤럭시노트7</b> 리퍼폰으로 재출시된다는 내용을 아침 출근길에 포털사이트 뉴스로 접했는데요^^ 아! 리퍼폰에 대해서 잘 모르시는분들도 있으실것같아서 간단히... ",
# "bloggername": "Laurant~Laurant~",
# "bloggerlink": "http://blog.naver.com/junhyuk0327",
# "postdate": "20170329"
#
# }
# ]
# }

# %%
import requests
import re
from bs4 import BeautifulSoup

base_url = 'http://www.cine21.com'
cine_url = '{}/rank/person/content'.format(base_url)

for i in range(1, 10):
    data = {}
    data['section'] = 'director'
    data['period_start'] = '2017-01'
    data['gender'] = 'all'
    data['page'] = i

    res = requests.post(cine_url, data = data)
    soup = BeautifulSoup(res.text)

    names = soup.find_all('div', attrs = {'class' : 'name'})
    for name in names:
        link = "{}{}".format(base_url, name.a['href'])
        print link
        #print requests.get(link).text
        #actor_name = re.sub('\(.+\)', '', actor_name)
        #print actor_name.encode('utf-8')
# Out:
# c:\python27\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file c:\python27\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html5lib")
#
#   markup_type=markup_type))
# http://www.cine21.com/db/person/info/?person_id=92022
# http://www.cine21.com/db/person/info/?person_id=22024
# http://www.cine21.com/db/person/info/?person_id=19632
# http://www.cine21.com/db/person/info/?person_id=16454
# http://www.cine21.com/db/person/info/?person_id=16958
# http://www.cine21.com/db/person/info/?person_id=9130
# http://www.cine21.com/db/person/info/?person_id=17990
# http://www.cine21.com/db/person/info/?person_id=102103
# http://www.cine21.com/db/person/info/?person_id=101518

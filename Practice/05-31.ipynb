# %%
import requests
from bs4 import BeautifulSoup

# %%
base_url = 'https://www.zigbang.com/search/map?lat=37.54906&amp;lng=126.9705&amp;zoom=8&amp;GGKW=google'

# %%
response = requests.get(base_url)

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# u'\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n    <meta charset="utf-8" />\r\n    <meta name="viewport" content="width=1140px">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge">\r\n\t<meta http-equiv="content-type" content="text/html; charset=utf-8">\r\n    <title>No.1 \ubd80\ub3d9\uc0b0 \uc571 \uc9c1\ubc29</title>\r\n\t<meta name="keywords" content="\uc6d0\ub8f8, \uc624\ud53c\uc2a4\ud154, \uc774\uc81c \uc544\ud30c\ud2b8\uae4c\uc9c0. \ubd80\ub3d9\uc0b0\uc740 \uc9c1\ubc29\ubd80\ud130!" />\r\n\t<meta name="description" content="\uc6d0\ub8f8, \uc624\ud53c\uc2a4\ud154, \uc774\uc81c \uc544\ud30c\ud2b8\uae4c\uc9c0. \ubd80\ub3d9\uc0b0\uc740 \uc9c1\ubc29\ubd80\ud130!" />\r\n    \r\n    <link rel="alternate" href="android-app://com.chbreeze.jikbang4a/zigbang/app/search/map">\r\n    <style>\r\n        .footer {display:none;}\r\n    </style>\r\n\r\n    \r\n    <meta property="og:url" content="https://www.zigbang.com"/>\r\n    <meta name="msapplication-TileImage" content="//s
# ...

# %%
dom = BeautifulSoup(response.content, 'html.parser',  from_encoding='utf-8')

# %%
room_elements = dom.select('div.list-item')

# %%
base_url = 'https://api.zigbang.com/v3/items?detail=true&item_ids=[8297544]'

# %%
response = requests.get(base_url)

# %%
jsno -> javascript object notation

# %%
import json

# %%
room_information = json.loads(response.text)

# %%
a = room_information['items'][0]['item']['agent_address1']

# %%
a.decode('utf-8').encode('utf-8')
# Out:
# '\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c \xec\x84\x9c\xec\xb4\x88\xea\xb5\xac \xea\xb0\x95\xeb\x82\xa8\xeb\x8c\x80\xeb\xa1\x9c 545-4 , 1\xec\xb8\xb5 (\xeb\xb0\x98\xed\x8f\xac\xeb\x8f\x99)'

# %%
string = item.decode('cp949')
worksheet.write(name_count,2, unicode(string))

# %%
import pandas as pd
pd.DataFrame(columns = ['address','deposit','rent'])

# %%
for room_id in range(8297844, 8297844+10 ):
    base_url = 'https://api.zigbang.com/v3/items?detail=true&item_ids=[8297544]'+room_id
    response = requests.get(base_url)
    room_information = json.loads(response.text)
    
    try:
        address = room_information['items'][0]['item']['agent_address1']
        deposit = room_information['items'][0]['item']['deposit']
        rent = room_information['items'][0]['item']['rent']
        print((address, deposit, rent))
        df.loc[len(df)] = [address, int(deposit), int(rent)]
    except:
        pass
